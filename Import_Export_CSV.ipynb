# %%
import pandas as pd
ranaumar = pd.DataFrame({
    "Student_ID": ["SU74-BSSEM-F23-018"],

    "Name": ["Rana Umar"],

    "University": ["Superior University"],

    "Department": ["Software Engineering"],

    "Semester": [6],

    "Email": ["ranaumar91920@gmail.com"],

    "City": ["Faisalabad"],

    "Country": ["Pakistan"],

    "Python": ["Learning"],

    "Machine Learning": ["Learning"],

    "Artificial Intelligence": ["Learning"],

    "LinkedIn": [
        "https://www.linkedin.com/in/rana-umar-draz-95951733b"
    ],

    "GitHub": ["Update Later"],

    "Research Topic": [
        "Hybrid Real-Time Fraud Detection in Online Transactions using Data Science, Machine Learning, and Optimization Techniques"
    ],

    "Internship Status": ["No"],

    "Skills": [

        "Python, Pandas, NumPy, ML Basics, Data Analysis, Power BI, Excel, SQL, Data Cleaning, Data Visualization, Flutter, Dart, Firebase, HTML, CSS, Bootstrap, JavaScript, MySQL, C++, OOP, GitHub, Problem Solving, MS Office, Entrepreneurship"

    ]

})

print(ranaumar)
print("Complete DataFrame")
print(ranaumar)
print("\nFirst Row")
print(ranaumar.head(1))
print("\nLast Row")
print(ranaumar.tail(1))
print("\nShape")
print(ranaumar.shape)
print("\nColumns")
print(ranaumar.columns)
print("\nData Types")
print(ranaumar.dtypes)
print("\nInformation")
print(ranaumar.info())
print("\nDescription")
print(ranaumar.describe(include="all"))
print("\nIndex")
print(ranaumar.index)

ranaumar.to_csv("ranaumar.csv", index=False)    #Save File

print("CSV File Exported Successfully")  


"""import pandas as pd

student = pd.read_csv("ranaumar.csv")         #Load File

print(student)"""
# Out:
#            Student_ID       Name           University            Department  \
# 0  SU74-BSSEM-F23-018  Rana Umar  Superior University  Software Engineering
#
#    Semester                    Email        City   Country    Python  \
# 0         6  ranaumar91920@gmail.com  Faisalabad  Pakistan  Learning
#
#   Machine Learning Artificial Intelligence  \
# 0         Learning                Learning
#
#                                             LinkedIn        GitHub  \
# 0  https://www.linkedin.com/in/rana-umar-draz-959...  Update Later
#
#                                       Research Topic Internship Status  \
# 0  Hybrid Real-Time Fraud Detection in Online Tra...                No
#
#                                               Skills
# 0  Python, Pandas, NumPy, ML Basics, Data Analysi...
# Complete DataFrame
#            Student_ID       Name           University            Department  \
# 0  SU74-BSSEM-F23-018  Rana Umar  Superior University  Software Engineering
#
#    Semester                    Email        City   Country    Python  \
# 0         6  ranaumar91920@gmail.com  Faisalabad  Pakistan  Learning
#
#   Machine Learning Artificial Intelligence  \
# 0         Learning                Learning
#
#                                             LinkedIn        GitHub  \
# 0  https://www.linkedin.com/in/rana-umar-draz-959...  Update Later
#
#                                       Research Topic Internship Status  \
# 0  Hybrid Real-Time Fraud Detection in Online Tra...                No
#
#                                               Skills
# 0  Python, Pandas, NumPy, ML Basics, Data Analysi...
#
# First Row
#            Student_ID       Name           University            Department  \
# 0  SU74-BSSEM-F23-018  Rana Umar  Superior University  Software Engineering
#
#    Semester                    Email        City   Country    Python  \
# 0         6  ranaumar91920@gmail.com  Faisalabad  Pakistan  Learning
#
#   Machine Learning Artificial Intelligence  \
# 0         Learning                Learning
#
#                                             LinkedIn        GitHub  \
# 0  https://www.linkedin.com/in/rana-umar-draz-959...  Update Later
#
#                                       Research Topic Internship Status  \
# 0  Hybrid Real-Time Fraud Detection in Online Tra...                No
#
#                                               Skills
# 0  Python, Pandas, NumPy, ML Basics, Data Analysi...
#
# Last Row
#            Student_ID       Name           University            Department  \
# 0  SU74-BSSEM-F23-018  Rana Umar  Superior University  Software Engineering
#
#    Semester                    Email        City   Country    Python  \
# 0         6  ranaumar91920@gmail.com  Faisalabad  Pakistan  Learning
#
#   Machine Learning Artificial Intelligence  \
# 0         Learning                Learning
#
#                                             LinkedIn        GitHub  \
# 0  https://www.linkedin.com/in/rana-umar-draz-959...  Update Later
#
#                                       Research Topic Internship Status  \
# 0  Hybrid Real-Time Fraud Detection in Online Tra...                No
#
#                                               Skills
# 0  Python, Pandas, NumPy, ML Basics, Data Analysi...
#
# Shape
# (1, 16)
#
# Columns
# Index(['Student_ID', 'Name', 'University', 'Department', 'Semester', 'Email',
#        'City', 'Country', 'Python', 'Machine Learning',
#        'Artificial Intelligence', 'LinkedIn', 'GitHub', 'Research Topic',
#        'Internship Status', 'Skills'],
#       dtype='object')
#
# Data Types
# Student_ID                 object
# Name                       object
# University                 object
# Department                 object
# Semester                    int64
# Email                      object
# City                       object
# Country                    object
# Python                     object
# Machine Learning           object
# Artificial Intelligence    object
# LinkedIn                   object
# GitHub                     object
# Research Topic             object
# Internship Status          object
# Skills                     object
# dtype: object
#
# Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Student_ID               1 non-null      object
#  1   Name                     1 non-null      object
#  2   University               1 non-null      object
#  3   Department               1 non-null      object
#  4   Semester                 1 non-null      int64
#  5   Email                    1 non-null      object
#  6   City                     1 non-null      object
#  7   Country                  1 non-null      object
#  8   Python                   1 non-null      object
#  9   Machine Learning         1 non-null      object
#  10  Artificial Intelligence  1 non-null      object
#  11  LinkedIn                 1 non-null      object
#  12  GitHub                   1 non-null      object
#  13  Research Topic           1 non-null      object
#  14  Internship Status        1 non-null      object
#  15  Skills                   1 non-null      object
# dtypes: int64(1), object(15)
# memory usage: 260.0+ bytes
# None
#
# Description
#                 Student_ID       Name           University  \
# count                    1          1                    1
# unique                   1          1                    1
# top     SU74-BSSEM-F23-018  Rana Umar  Superior University
# freq                     1          1                    1
# mean                   NaN        NaN                  NaN
# std                    NaN        NaN                  NaN
# min                    NaN        NaN                  NaN
# 25%                    NaN        NaN                  NaN
# 50%                    NaN        NaN                  NaN
# 75%                    NaN        NaN                  NaN
# max                    NaN        NaN                  NaN
#
#                   Department  Semester                    Email        City  \
# count                      1       1.0                        1           1
# unique                     1       NaN                        1           1
# top     Software Engineering       NaN  ranaumar91920@gmail.com  Faisalabad
# freq                       1       NaN                        1           1
# mean                     NaN       6.0                      NaN         NaN
# std                      NaN       NaN                      NaN         NaN
# min                      NaN       6.0                      NaN         NaN
# 25%                      NaN       6.0                      NaN         NaN
# 50%                      NaN       6.0                      NaN         NaN
# 75%                      NaN       6.0                      NaN         NaN
# max                      NaN       6.0                      NaN         NaN
#
#          Country    Python Machine Learning Artificial Intelligence  \
# count          1         1                1                       1
# unique         1         1                1                       1
# top     Pakistan  Learning         Learning                Learning
# freq           1         1                1                       1
# mean         NaN       NaN              NaN                     NaN
# std          NaN       NaN              NaN                     NaN
# min          NaN       NaN              NaN                     NaN
# 25%          NaN       NaN              NaN                     NaN
# 50%          NaN       NaN              NaN                     NaN
# 75%          NaN       NaN              NaN                     NaN
# max          NaN       NaN              NaN                     NaN
#
#                                                  LinkedIn        GitHub  \
# count                                                   1             1
# unique                                                  1             1
# top     https://www.linkedin.com/in/rana-umar-draz-959...  Update Later
# freq                                                    1             1
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#                                            Research Topic Internship Status  \
# count                                                   1                 1
# unique                                                  1                 1
# top     Hybrid Real-Time Fraud Detection in Online Tra...                No
# freq                                                    1                 1
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#                                                    Skills
# count                                                   1
# unique                                                  1
# top     Python, Pandas, NumPy, ML Basics, Data Analysi...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# Index
# RangeIndex(start=0, stop=1, step=1)
# CSV File Exported Successfully
# 'import pandas as pd\n\nstudent = pd.read_csv("ranaumar.csv")         #Load File\n\nprint(student)'
